# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("IPL 2020 - CSK.csv")
df
# Out:
#                   Name Team    Nationality                  Matches  \
# 0         MS Dhoni (c)  CSK         Indian                      190
# 1          Imran Tahir  CSK  South African                       55
# 2          Lungi Ngidi  CSK  South African                        7
# 3      Ruturaj Gaikwad  CSK         Indian  No Past IPL Stats Found
# 4         Shane Watson  CSK     Australian                      134
# 5        Ambati Rayudu  CSK         Indian                      147
# 6         Murali Vijay  CSK         Indian                      103
# 7         Kedar Jadhav  CSK         Indian                       79
# 8      Ravindra Jadeja  CSK         Indian                      170
# 9        Deepak Chahar  CSK         Indian                       34
# 10       Piyush Chawla  CSK         Indian                      157
# 11  Narayan Jagadeesan  CSK         Indian  No Past IPL Stats Found
# 12    Mitchell Santner  CSK  New Zealander                        4
# ...

# %%
df = pd.read_csv("IPL 2020 - CSK.csv" ,usecols = ['Name','Team','Nationality','Matches','Bat-Runs','Bat-Highest Score','Bat- Average','Bat- Balls Faced','5W'] ,skiprows = [2,13],dtype{'Bat- Average':int})
# Out:
#   File "<ipython-input-107-32ad760d9cca>", line 1
#     df = pd.read_csv("IPL 2020 - CSK.csv" ,usecols = ['Name','Team','Nationality','Matches','Bat-Runs','Bat-Highest Score','Bat- Average','Bat- Balls Faced','5W'] ,skiprows = [2,13],dtype{'Bat- Average':int})
#                                                                                                                                                                                            ^
# SyntaxError: invalid syntax

# %%
df.shape
# Out:
# (20, 9)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Team                 0
# Nationality          0
# Matches              0
# Bat-Runs             5
# Bat-Highest Score    5
# Bat- Average         5
# Bat- Balls Faced     5
# 5W                   5
# dtype: int64

# %%
df
# Out:
#                   Name Team    Nationality                  Matches  Bat-Runs  \
# 0         MS Dhoni (c)  CSK         Indian                      190    4432.0
# 1          Lungi Ngidi  CSK  South African                        7       0.0
# 2      Ruturaj Gaikwad  CSK         Indian  No Past IPL Stats Found       NaN
# 3         Shane Watson  CSK     Australian                      134    3575.0
# 4        Ambati Rayudu  CSK         Indian                      147    3300.0
# 5         Murali Vijay  CSK         Indian                      103    2587.0
# 6         Kedar Jadhav  CSK         Indian                       79    1079.0
# 7      Ravindra Jadeja  CSK         Indian                      170    1927.0
# 8        Deepak Chahar  CSK         Indian                       34      71.0
# 9        Piyush Chawla  CSK         Indian                      157     584.0
# 10  Narayan Jagadeesan  CSK         Indian  No Past IPL Stats Found       NaN
# ...

# %%
df.shape
# Out:
# (20, 9)

# %%
df.head()
# Out:
#               Name Team    Nationality                  Matches  Bat-Runs  \
# 0     MS Dhoni (c)  CSK         Indian                      190    4432.0
# 1      Lungi Ngidi  CSK  South African                        7       0.0
# 2  Ruturaj Gaikwad  CSK         Indian  No Past IPL Stats Found       NaN
# 3     Shane Watson  CSK     Australian                      134    3575.0
# 4    Ambati Rayudu  CSK         Indian                      147    3300.0
#
#   Bat-Highest Score Bat- Average Bat- Balls Faced   5W
# 0               84*         42.2            3,215  0.0
# 1                0*            -                0  0.0
# 2               NaN          NaN              NaN  NaN
# 3              117*        31.08            2,562  0.0
# 4              100*        28.69            2,620  0.0

# %%
df.tail()
# Out:
#               Name Team  Nationality                  Matches  Bat-Runs  \
# 15      Monu Kumar  CSK       Indian  No Past IPL Stats Found       NaN
# 16    Dwayne Bravo  CSK  West Indian                      134    1483.0
# 17  Josh Hazlewood  CSK   Australian  No Past IPL Stats Found       NaN
# 18      Sam Curran  CSK      English                        9      95.0
# 19     Karn Sharma  CSK       Indian                       62     316.0
#
#    Bat-Highest Score Bat- Average Bat- Balls Faced   5W
# 15               NaN          NaN              NaN  NaN
# 16               70*        23.17            1,156  0.0
# 17               NaN          NaN              NaN  NaN
# 18               55*        23.75               55  0.0
# 19               39*         15.8              271  0.0

# %%
df.isnull().sum()
# Out:
# Name                 0
# Team                 0
# Nationality          0
# Matches              0
# Bat-Runs             5
# Bat-Highest Score    5
# Bat- Average         5
# Bat- Balls Faced     5
# 5W                   5
# dtype: int64

# %%
df.describe()
# Out:
#           Bat-Runs         5W
# count    15.000000  15.000000
# mean   1422.533333   0.066667
# std    1478.864036   0.258199
# min       0.000000   0.000000
# 25%      83.000000   0.000000
# 50%    1079.000000   0.000000
# 75%    2257.000000   0.000000
# max    4432.000000   1.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.skiprows=1
df
# Out:
#                   Name Team    Nationality                  Matches  Bat-Runs  \
# 0         MS Dhoni (c)  CSK         Indian                      190    4432.0
# 1          Lungi Ngidi  CSK  South African                        7       0.0
# 2      Ruturaj Gaikwad  CSK         Indian  No Past IPL Stats Found       NaN
# 3         Shane Watson  CSK     Australian                      134    3575.0
# 4        Ambati Rayudu  CSK         Indian                      147    3300.0
# 5         Murali Vijay  CSK         Indian                      103    2587.0
# 6         Kedar Jadhav  CSK         Indian                       79    1079.0
# 7      Ravindra Jadeja  CSK         Indian                      170    1927.0
# 8        Deepak Chahar  CSK         Indian                       34      71.0
# 9        Piyush Chawla  CSK         Indian                      157     584.0
# 10  Narayan Jagadeesan  CSK         Indian  No Past IPL Stats Found       NaN
# ...

# %%
sns.countplot(df['Team'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='count'>

# %%
sns.countplot(df['Nationality'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Nationality', ylabel='count'>

# %%
df['Nationality'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='Nationality'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-6df6029f8a4b> in <module>
# ----> 1 df = df[['Bat- Average'== int]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2937             )
#    2938         elif len(key) != len(self.index):
# -> 2939             raise ValueError(
#    2940                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2941             )
#
# ValueError: Item wrong length 1 instead of 20.

# %%
plt.hist(df['Bat- Average'] ,bins=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-ef262eef8a50> in <module>
# ----> 1 plt.hist(df['Bat- Average'] ,bins=50)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...
